# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder\
    .appName("Read CSV Example")\
    .getOrCreate()

# %%
raw_data = [
    ("U001","Abhishek",28,"Hyderabad",50000),
    ("U002","Neha",32,"Delhi",62000),
    ("U003","Ravi",25,"Bangalore",45000),
    ("U004","Pooja",29,"Mumbai",58000)
]

# %%
from pyspark.sql.types import(
    StructType,StructField,
    StringType,IntegerType,LongType
)
user_schema=StructType([
    StructField("user_id",StringType(),nullable=False),
    StructField("name",StringType(),nullable=True),
    StructField("age",IntegerType(),nullable=True),
    StructField("city",StringType(),nullable=True),
    StructField("salary",LongType(),nullable=True)

])
df_users=spark.createDataFrame(raw_data,schema=user_schema)
df_users.printSchema()
df_users.show()
#wrong data
raw_data2=[
    ("U005","Amit","Thirty","Chennai",400000)

]
df_users=spark.createDataFrame(raw_data2,schema=user_schema)
# Out:
# root
#  |-- user_id: string (nullable = false)
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- city: string (nullable = true)
#  |-- salary: long (nullable = true)
#
# +-------+--------+---+---------+------+
# |user_id|    name|age|     city|salary|
# +-------+--------+---+---------+------+
# |   U001|Abhishek| 28|Hyderabad| 50000|
# |   U002|    Neha| 32|    Delhi| 62000|
# |   U003|    Ravi| 25|Bangalore| 45000|
# |   U004|   Pooja| 29|   Mumbai| 58000|
# +-------+--------+---+---------+------+
# ---------------------------------------------------------------------------
# PySparkTypeError                          Traceback (most recent call last)
# /tmp/ipython-input-3091272204.py in <cell line: 0>()
#      19
#      20 ]
# ---> 21 df_users=spark.createDataFrame(raw_data2,schema=user_schema)
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in createDataFrame(self, data, schema, samplingRatio, verifySchema)
#    1597                 data, schema, samplingRatio, verifySchema
#    1598             )
# -> 1599         return self._create_dataframe(
#    1600             data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#    1601         )
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in _create_dataframe(self, data, schema, samplingRatio, verifySchema)
#    1641             rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#    1642         else:
# -> 1643             rdd, struct = self._createFromLocal(
#    1644                 map(prepare, data), schema  # type: ignore[arg-type]
#    1645             )
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in _createFromLocal(self, data, schema)
#    1193         # make sure data could consumed multiple times
#    1194         if not isinstance(data, list):
# -> 1195             data = list(data)
#    1196
#    1197         if schema is None or isinstance(schema, (list, tuple)):
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in prepare(obj)
#    1613             @no_type_check
#    1614             def prepare(obj):
# -> 1615                 verify_func(obj)
#    1616                 return obj
#    1617
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/types.py in verify(obj)
#    2974     def verify(obj: Any) -> None:
#    2975         if not verify_nullability(obj):
# -> 2976             verify_value(obj)
#    2977
#    2978     return verify
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/types.py in verify_struct(obj)
#    2929                     )
#    2930                 for v, (_, verifier) in zip(obj, verifiers):
# -> 2931                     verifier(v)
#    2932             elif hasattr(obj, "__dict__"):
#    2933                 d = obj.__dict__
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/types.py in verify(obj)
#    2974     def verify(obj: Any) -> None:
#    2975         if not verify_nullability(obj):
# -> 2976             verify_value(obj)
#    2977
#    2978     return verify
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/types.py in verify_integer(obj)
#    2834         def verify_integer(obj: Any) -> None:
#    2835             assert_acceptable_types(obj)
# -> 2836             verify_acceptable_types(obj)
#    2837             lower_bound = -2147483648
#    2838             upper_bound = 2147483647
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/types.py in verify_acceptable_types(obj)
#    2742         if type(obj) not in _acceptable_types[_type]:
#    2743             if name is not None:
# -> 2744                 raise PySparkTypeError(
#    2745                     errorClass="FIELD_DATA_TYPE_UNACCEPTABLE_WITH_NAME",
#    2746                     messageParameters={
#
# PySparkTypeError: [FIELD_DATA_TYPE_UNACCEPTABLE_WITH_NAME] field age: IntegerType() can not accept object 'Thirty' in type <class 'str'>.

# %%
from pyspark.sql.types import ArrayType

# %%
interest_data = [
    ("U001",["AI","ML","Cloud"]),
    ("U002",["Testing","Automation"]),
    ("U003",["Data Engineering","Spark","Kafka"]),
    ("U004",["UI/UX"])
]

# %%
interest_schema=StructType([
    StructField("user_id",StringType(),False),
    StructField("interests",ArrayType(StringType()),True)
])

# %%
df_interests=spark.createDataFrame(interest_data,schema=interest_schema)
df_interests.printSchema()
df_interests.show(truncate=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3374199207.py in <cell line: 0>()
# ----> 1 df_interests=spark.createDataFrame(interest_data,schema=interest_schema)
#       2 df_interests.printSchema()
#       3 df_interests.show(truncate=False)
#
# NameError: name 'interest_schema' is not defined

# %%
from pyspark.sql.functions import col,explode
df_interests.select(
    "user_id",
    explode("interests").alias("interest")
).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2108379701.py in <cell line: 0>()
#       1 from pyspark.sql.functions import col,explode
# ----> 2 df_interests.select(
#       3     "user_id",
#       4     explode("interests").alias("interest")
#       5 ).show()
#
# NameError: name 'df_interests' is not defined

# %%
from pyspark.sql.types import MapType

# %%
device_data = [
    ("U001",{"mobile":120,"laptop":300}),
    ("U002",{"tablet":80}),
    ("U003",{"mobile":200,"desktop":400}),
    ("U004",{"laptop":250})
]

# %%
device_Schema=StructType([
    StructField("user_id",StringType(),False),
    StructField("devices",MapType(stringType(),IntegerType()),True)
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2564723014.py in <cell line: 0>()
# ----> 1 device_Schema=StructType([
#       2     StructField("user_id",StringType(),False),
#       3     StructField("devices",MapType(stringType(),IntegerType()),True)
#       4 ])
#
# NameError: name 'StructType' is not defined

# %%
df_devices=spark.createDataFrame(device_data,schema=device_Schema)
df_devices.printSchema()
df_devices.show(truncate=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2417588970.py in <cell line: 0>()
# ----> 1 df_devices=spark.createDataFrame(device_data,schema=device_Schema)
#       2 df_devices.printSchema()
#       3 df_devices.show(truncate=False)
#
# NameError: name 'device_Schema' is not defined

# %%
nested_data = [
    ("U001",("Hyderabad","Telangana",500081)),
    ("U002",("Delhi","Delhi",110001)),
    ("U003",("Bangalore","Karnataka",560001))
]

# %%
address_schema=StructType([
    StructField("city",StringType(),True),
    StructField("state",StringType(),True),
    StructField("pincode",StringType(),True)
])
profile_schema=StructType([
    StructField("user_id",StringType(),False),
    StructField("address",address_schema,True)
])

# %%
df_profiles=spark.createDataFrame(nested_data,profile_schema)
df_profiles.printSchema()
df_profiles.show(truncate=False)
# Out:
# root
#  |-- user_id: string (nullable = false)
#  |-- address: struct (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- state: string (nullable = true)
#  |    |-- pincode: string (nullable = true)
#
# +-------+------------------------------+
# |user_id|address                       |
# +-------+------------------------------+
# |U001   |{Hyderabad, Telangana, 500081}|
# |U002   |{Delhi, Delhi, 110001}        |
# |U003   |{Bangalore, Karnataka, 560001}|
# +-------+------------------------------+

# %%
df_profiles.select(
    "user_id",
    "address.city",
    "address.state",

).show()
# Out:
# +-------+---------+---------+
# |user_id|     city|    state|
# +-------+---------+---------+
# |   U001|Hyderabad|Telangana|
# |   U002|    Delhi|    Delhi|
# |   U003|Bangalore|Karnataka|
# +-------+---------+---------+

# %%
from pyspark.sql.functions import col
df_users.withColumn(
    "salary_int",
    col("salary").cast("int")
)
# Out:
# DataFrame[user_id: string, name: string, age: int, city: string, salary: bigint, salary_int: int]

# %%
from pyspark.sql.functions import to_date
df_orders.withColumn(
    "order_date",
    to_date("order_date","yyyy-MM-dd")
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4210798079.py in <cell line: 0>()
#       1 from pyspark.sql.functions import to_date
# ----> 2 df_orders.withColumn(
#       3     "order_date",
#       4     to_date("order_date","yyyy-MM-dd")
#       5 )
#
# NameError: name 'df_orders' is not defined
