# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder\
    .appName("Read CSV Example")\
    .getOrCreate()

# %%
df=spark.read\
    .option("header","true")\
    .option("inferSchema","true")\
    .csv("traffic_data_large.csv")

# %%
df.printSchema()
# Out:
# root
#  |-- sensor_id: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- road_name: string (nullable = true)
#  |-- vehicle_count: string (nullable = true)
#  |-- avg_speed: double (nullable = true)
#  |-- temperature: integer (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- status: string (nullable = true)

# %%
df.count()
# Out:
# 500000

# %%
from pyspark.sql import functions as F
for c in df.columns:
    df=df.withColumn(c,F.trim(F.col(c)))

# %%
df=df.withColumn("vehicle_count_clean",F.when(F.col("vehicle_count").rlike("^[0-9]+$"),F.col("vehicle_count").cast("int")))

# %%
df=df.withColumn("avg_speed_clean",F.col("avg_speed").cast("double"))

# %%
df = df.withColumn(
    "event_time",
    F.coalesce(
        F.to_timestamp("timestamp", "yyyy-MM-dd HH:mm:ss"),
        F.to_timestamp("timestamp", "dd/MM/yyyy HH:mm:ss"),
        F.to_timestamp("timestamp", "yyyy/MM/dd HH:mm:ss")
    ))

# %% [markdown]
# phase 3

# %%
df.filter(F.col("vehicle_count_clean").isNull()).count()
# Out:
# 49873

# %%
df.filter(F.col("event_time").isNull()).count()

# %%
clean_df=df.filter(F.col("status")=="ACTIVE")

# %%
clean_df.groupBy("road_name")\
.agg(F.sum("vehicle_count_clean").alias("total_vehicle_count"))
# Out:
# DataFrame[road_name: string, total_vehicle_count: bigint]

# %%
clean_df.groupBy("location",F.hour("event_time").alias("hour"))\
.agg(F.sum("vehicle_count_clean").alias("total_vehicle_count"))\
.orderBy("vehicles",ascending=False)

# %%
clean_df.groupBy("road_name")\
.agg(F.avg("avg_speed_clean").alias("avg_speed"))\
.orderBy("avg_speed",ascending=False)
# Out:
# DataFrame[road_name: string, avg_speed: double]

# %%
from pyspark.sql.window import Window
road_window = Window.orderBy("avg_speed")
loc_window = Window.partitionBy("location").orderBy(F.desc("vehicle_count_clean"))

# %%
congestion_rank = clean_df.groupBy("road_name") \
    .agg(F.avg("avg_speed_clean").alias("avg_speed")) \
    .withColumn("rank", F.rank().over(road_window))

# %%
ranked_roads = clean_df.withColumn("rank", F.rank().over(loc_window))

# %%
ranked_roads.filter(F.col("rank") <= 3)
# Out:
# DataFrame[sensor_id: string, location: string, road_name: string, vehicle_count: string, avg_speed: string, temperature: string, timestamp: string, status: string, vehicle_count_clean: int, avg_speed_clean: double, event_time: timestamp, rank: int]

# %%
w=Window.partitionBy("sensor_id").orderBy("event_time")

# %%
clean_df.withColumn("prev_speed",F.lag("avg_speed_clean").over(w)).filter(F.col("avg_speed_clean")<F.col("prev_speed")*0.7)
# Out:
# DataFrame[sensor_id: string, location: string, road_name: string, vehicle_count: string, avg_speed: string, temperature: string, timestamp: string, status: string, vehicle_count_clean: int, avg_speed_clean: double, event_time: timestamp, prev_speed: double]

# %%
clean_df.withColumn("prev_count",F.lag("vehicle_count_clean").over(w)).filter(F.col("vehicle_count_clean")<F.col("prev_count")*1.5)
# Out:
# DataFrame[sensor_id: string, location: string, road_name: string, vehicle_count: string, avg_speed: string, temperature: string, timestamp: string, status: string, vehicle_count_clean: int, avg_speed_clean: double, event_time: timestamp, prev_count: int]

# %%
clean_df.rdd.getNumPartitions()
clean_df.cache()
clean_df.explain(True)
clean_df=clean_df.repartition("location")
# Out:
# == Parsed Logical Plan ==
# 'Filter '`=`('status, ACTIVE)
# +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, status#53, vehicle_count_clean#91, avg_speed_clean#100, coalesce(to_timestamp(timestamp#52, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), true), to_timestamp(timestamp#52, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), true), to_timestamp(timestamp#52, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), true)) AS event_time#101]
#    +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, status#53, vehicle_count_clean#91, cast(avg_speed#50 as double) AS avg_speed_clean#100]
#       +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, status#53, CASE WHEN RLIKE(vehicle_count#49, ^[0-9]+$) THEN cast(vehicle_count#49 as int) END AS vehicle_count_clean#91]
#          +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, status#53, CASE WHEN RLIKE(vehicle_count#49, ^[0-9]+$) THEN cast(vehicle_count#49 as int) END AS Vehicle_count_clean#62]
#             +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, trim(status#24, None) AS status#53]
#                +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, trim(timestamp#23, None) AS timestamp#52, status#24]
#                   +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, trim(cast(temperature#22 as string), None) AS temperature#51, timestamp#23, status#24]
#                      +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, trim(cast(avg_speed#21 as string), None) AS avg_speed#50, temperature#22, timestamp#23, status#24]
#                         +- Project [sensor_id#46, location#47, road_name#48, trim(vehicle_count#20, None) AS vehicle_count#49, avg_speed#21, temperature#22, timestamp#23, status#24]
#                            +- Project [sensor_id#46, location#47, trim(road_name#19, None) AS road_name#48, vehicle_count#20, avg_speed#21, temperature#22, timestamp#23, status#24]
#                               +- Project [sensor_id#46, trim(location#18, None) AS location#47, road_name#19, vehicle_count#20, avg_speed#21, temperature#22, timestamp#23, status#24]
#                                  +- Project [trim(sensor_id#17, None) AS sensor_id#46, location#18, road_name#19, vehicle_count#20, avg_speed#21, temperature#22, timestamp#23, status#24]
#                                     +- Relation [sensor_id#17,location#18,road_name#19,vehicle_count#20,avg_speed#21,temperature#22,timestamp#23,status#24] csv
#
# == Analyzed Logical Plan ==
# sensor_id: string, location: string, road_name: string, vehicle_count: string, avg_speed: string, temperature: string, timestamp: string, status: string, vehicle_count_clean: int, avg_speed_clean: double, event_time: timestamp
# Filter (status#53 = ACTIVE)
# +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, status#53, vehicle_count_clean#91, avg_speed_clean#100, coalesce(to_timestamp(timestamp#52, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), true), to_timestamp(timestamp#52, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), true), to_timestamp(timestamp#52, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), true)) AS event_time#101]
#    +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, status#53, vehicle_count_clean#91, cast(avg_speed#50 as double) AS avg_speed_clean#100]
#       +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, status#53, CASE WHEN RLIKE(vehicle_count#49, ^[0-9]+$) THEN cast(vehicle_count#49 as int) END AS vehicle_count_clean#91]
#          +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, status#53, CASE WHEN RLIKE(vehicle_count#49, ^[0-9]+$) THEN cast(vehicle_count#49 as int) END AS Vehicle_count_clean#62]
#             +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, trim(status#24, None) AS status#53]
#                +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, trim(timestamp#23, None) AS timestamp#52, status#24]
#                   +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, trim(cast(temperature#22 as string), None) AS temperature#51, timestamp#23, status#24]
#                      +- Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, trim(cast(avg_speed#21 as string), None) AS avg_speed#50, temperature#22, timestamp#23, status#24]
#                         +- Project [sensor_id#46, location#47, road_name#48, trim(vehicle_count#20, None) AS vehicle_count#49, avg_speed#21, temperature#22, timestamp#23, status#24]
#                            +- Project [sensor_id#46, location#47, trim(road_name#19, None) AS road_name#48, vehicle_count#20, avg_speed#21, temperature#22, timestamp#23, status#24]
#                               +- Project [sensor_id#46, trim(location#18, None) AS location#47, road_name#19, vehicle_count#20, avg_speed#21, temperature#22, timestamp#23, status#24]
#                                  +- Project [trim(sensor_id#17, None) AS sensor_id#46, location#18, road_name#19, vehicle_count#20, avg_speed#21, temperature#22, timestamp#23, status#24]
#                                     +- Relation [sensor_id#17,location#18,road_name#19,vehicle_count#20,avg_speed#21,temperature#22,timestamp#23,status#24] csv
#
# == Optimized Logical Plan ==
# Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, status#53, CASE WHEN RLIKE(vehicle_count#49, ^[0-9]+$) THEN cast(vehicle_count#49 as int) END AS vehicle_count_clean#91, cast(avg_speed#50 as double) AS avg_speed_clean#100, coalesce(gettimestamp(timestamp#52, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), true), gettimestamp(timestamp#52, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), true), gettimestamp(timestamp#52, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), true)) AS event_time#101]
# +- Project [trim(sensor_id#17, None) AS sensor_id#46, trim(location#18, None) AS location#47, trim(road_name#19, None) AS road_name#48, trim(vehicle_count#20, None) AS vehicle_count#49, trim(cast(avg_speed#21 as string), None) AS avg_speed#50, trim(cast(temperature#22 as string), None) AS temperature#51, trim(timestamp#23, None) AS timestamp#52, trim(status#24, None) AS status#53]
#    +- Filter (trim(status#24, None) = ACTIVE)
#       +- Relation [sensor_id#17,location#18,road_name#19,vehicle_count#20,avg_speed#21,temperature#22,timestamp#23,status#24] csv
#
# == Physical Plan ==
# *(1) Project [sensor_id#46, location#47, road_name#48, vehicle_count#49, avg_speed#50, temperature#51, timestamp#52, status#53, CASE WHEN RLIKE(vehicle_count#49, ^[0-9]+$) THEN cast(vehicle_count#49 as int) END AS vehicle_count_clean#91, cast(avg_speed#50 as double) AS avg_speed_clean#100, coalesce(gettimestamp(timestamp#52, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), true), gettimestamp(timestamp#52, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), true), gettimestamp(timestamp#52, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), true)) AS event_time#101]
# +- *(1) Project [trim(sensor_id#17, None) AS sensor_id#46, trim(location#18, None) AS location#47, trim(road_name#19, None) AS road_name#48, trim(vehicle_count#20, None) AS vehicle_count#49, trim(cast(avg_speed#21 as string), None) AS avg_speed#50, trim(cast(temperature#22 as string), None) AS temperature#51, trim(timestamp#23, None) AS timestamp#52, trim(status#24, None) AS status#53]
#    +- *(1) Filter (trim(status#24, None) = ACTIVE)
#       +- FileScan csv [sensor_id#17,location#18,road_name#19,vehicle_count#20,avg_speed#21,temperature#22,timestamp#23,status#24] Batched: false, DataFilters: [(trim(status#24, None) = ACTIVE)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/traffic_data_large.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sensor_id:string,location:string,road_name:string,vehicle_count:string,avg_speed:double,te...

# %%
traffic_rdd=clean_df.rdd

# %%
traffic_rdd.map(lambda x:x.vehicle_count_clean or 0).reduce(lambda x,y:x+y)

# %%
traffic_rdd.map(lambda x:(x.location,1))\
.reduceByKey(lambda a,b:a+b)

# %%
slow_roads = clean_df.filter(F.col("avg_speed_clean") < 25).select("road_name")
busy_roads = clean_df.filter(F.col("vehicle_count_clean") > 60).select("road_name")
slow_roads.intersect(busy_roads)
slow_roads.subtract(busy_roads)
# Out:
# DataFrame[road_name: string]

# %%
clean_df.write \
    .mode("overwrite") \
    .partitionBy("location") \
    .parquet("traffic_parquet")

# %%
congestion_rank.write \
    .mode("overwrite") \
    .orc("traffic_congestion_orc")

# %%
spark.read.parquet("traffic_parquet").show()
spark.read.orc("traffic_congestion_orc").show()
