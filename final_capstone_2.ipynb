# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder\
    .appName("Read CSV Example")\
    .getOrCreate()

# %%
df=spark.read\
    .option("header","true")\
    .option("inferSchema","true")\
    .csv("orders.csv")

# %%
from pyspark.sql.functions import trim,col
df=df.withColumn("city",trim(col("city")))\
     .withColumn("category",trim(col("category")))\
     .withColumn("product",trim(col("product")))

# %%
from pyspark.sql.functions import initcap
df=df.withColumn("city",initcap(col("city")))\
     .withColumn("category",initcap(col("category")))\
     .withColumn("product",initcap(col("product")))

# %%
from pyspark.sql.functions import when,regexp_replace
df=df.withColumn("amount_clean",regexp_replace(col("amount"),",",""))
df=df.withColumn("amount_int",when(col("amount_clean").rlike("^[0-9]+$"),
                    col("amount_clean").cast("int"))
                  .otherwise(None))

# %%
from pyspark.sql.functions import to_date,coalesce
df=df.withColumn("order_date_clean",
                 coalesce(
                     to_date(col("order_date"),"yyyy-MM-dd"),
                     to_date(col("order_date"),"dd/MM/yyyy"),
                     to_date(col("order_date"),"yyyy/MM/dd")
                 ))

# %%
df=df.dropDuplicates(["order_id"])
df=df.filter(col("status")=="Completed")

# %%
clean_orders_df=df

# %%
from pyspark.sql.functions import count, sum, avg, min, max, countDistinct

customer_metrics = clean_orders_df.groupBy("customer_id").agg(
    count("*").alias("total_orders"),
    sum("amount_int").alias("total_spend"),
    avg("amount_int").alias("avg_order_value"),
    min("order_date_clean").alias("first_purchase"),
    max("order_date_clean").alias("last_purchase"),
    countDistinct("city").alias("cities_count"),
    countDistinct("category").alias("categories_count")
)

# %%
from pyspark.sql.functions import when
customer_segmented = customer_metrics.withColumn(
    "customer_segment",
    when((col("total_spend") >= 200000) & (col("total_orders") >= 5), "VIP")
    .when(col("total_spend") >= 100000, "Premium")
    .otherwise("Regular")
)

# %%
customer_segmented.groupBy("customer_segment").count()
# Out:
# DataFrame[customer_segment: string, count: bigint]

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import rank
w_overall=Window.orderBy(col("total_spend").desc())
customer_segmented=customer_segmented.withColumn("overall_rank",rank().over(w_overall))

# %%
customer_city_spend = clean_orders_df.groupBy(
    "city", "customer_id"
).sum("amount_int").withColumnRenamed("sum(amount_int)", "city_spend")
w_city = Window.partitionBy("city").orderBy(col("city_spend").desc())
customer_city_rank = customer_city_spend.withColumn(
    "city_rank",
    rank().over(w_city))

# %%
#top 3 city
customer_city_rank.filter(col("city_rank")<=3)
# Out:
# DataFrame[city: string, customer_id: string, city_spend: bigint, city_rank: int]

# %%
#top 10
customer_segmented.filter(col("overall_rank")<=10)
# Out:
# DataFrame[customer_id: string, total_orders: bigint, total_spend: bigint, avg_order_value: double, first_purchase: date, last_purchase: date, cities_count: bigint, categories_count: bigint, customer_segment: string, overall_rank: int]

# %%
#define loyalty
loyal_customers = clean_orders_df.groupBy("customer_id").agg(
    countDistinct("order_date_clean").alias("purchase_days"),
    countDistinct("category").alias("category_count")
).filter(
    (col("purchase_days") >= 3) & (col("category_count") >= 2))

# %%
#loyal per city
clean_orders_df.join(loyal_customers,"customer_id")\
.groupBy("city").count()
# Out:
# DataFrame[city: string, count: bigint]

# %%
clean_orders_df.join(loyal_customers, "customer_id", "left") \
    .withColumn("loyal_flag",
                when(loyal_customers.customer_id.isNotNull(), "Loyal")
                .otherwise("Non-Loyal")) \
    .groupBy("loyal_flag") \
    .sum("amount_int")
# Out:
# DataFrame[loyal_flag: string, sum(amount_int): bigint]

# %%
#time based analysis
from pyspark.sql.functions import year, month, quarter
monthly_df=clean_orders_df.withColumn("year",year(col("order_date_clean")))\
                          .withColumn("month",month(col("order_date_clean")))

# %%
#monthly
monthly_df.groupBy("year","month","city")\
.sum("amount_int")
# Out:
# DataFrame[year: int, month: int, city: string, sum(amount_int): bigint]

# %%
monthly_df.groupBy("year","month","category")\
.count()
# Out:
# DataFrame[year: int, month: int, category: string, count: bigint]

# %%
#performance engineering
customer_segmented.cache()
customer_segmented.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Project [unresolvedstarwithcolumns(overall_rank, 'rank() windowspecdefinition('total_spend DESC NULLS LAST, unspecifiedframe$()), None)]
# +- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, CASE WHEN ((total_spend#501L >= cast(200000 as bigint)) AND (total_orders#500L >= cast(5 as bigint))) THEN VIP WHEN (total_spend#501L >= cast(100000 as bigint)) THEN Premium ELSE Regular END AS customer_segment#525]
#    +- Aggregate [customer_id#18], [customer_id#18, count(1) AS total_orders#500L, sum(amount_int#33) AS total_spend#501L, avg(amount_int#33) AS avg_order_value#502, min(order_date_clean#35) AS first_purchase#503, max(order_date_clean#35) AS last_purchase#504, count(distinct city#29) AS cities_count#505L, count(distinct category#30) AS categories_count#506L]
#       +- Filter (status#24 = Completed)
#          +- Deduplicate [order_id#17]
#             +- Filter (status#24 = Completed)
#                +- Deduplicate [order_id#17]
#                   +- Filter (status#24 = Completed)
#                      +- Deduplicate [order_id#17]
#                         +- Deduplicate [order_id#17]
#                            +- Filter (status#24 = Completed)
#                               +- Deduplicate [order_id#17]
#                                  +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, amount_int#33, coalesce(to_date(order_date#23, Some(yyyy-MM-dd), Some(Etc/UTC), true), to_date(order_date#23, Some(dd/MM/yyyy), Some(Etc/UTC), true), to_date(order_date#23, Some(yyyy/MM/dd), Some(Etc/UTC), true)) AS order_date_clean#35]
#                                     +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, amount_int#33, coalesce(to_date(order_date#23, Some(yyyy-MM-dd), Some(Etc/UTC), true), to_date(order_date#23, Some(dd/MM/yyyy), Some(Etc/UTC), true), to_date(order_date#23, Some(yyyy/M/dd), Some(Etc/UTC), true)) AS order_date_clean#34]
#                                        +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, CASE WHEN RLIKE(amount_clean#32, ^[0-9]+$) THEN cast(amount_clean#32 as int) ELSE cast(null as int) END AS amount_int#33]
#                                           +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, regexp_replace(amount#22, ,, , 1) AS amount_clean#32]
#                                              +- Project [order_id#17, customer_id#18, city#29, category#30, initcap(product#28) AS product#31, amount#22, order_date#23, status#24]
#                                                 +- Project [order_id#17, customer_id#18, city#29, initcap(category#27) AS category#30, product#28, amount#22, order_date#23, status#24]
#                                                    +- Project [order_id#17, customer_id#18, initcap(city#26) AS city#29, category#27, product#28, amount#22, order_date#23, status#24]
#                                                       +- Project [order_id#17, customer_id#18, city#26, category#27, trim(product#21, None) AS product#28, amount#22, order_date#23, status#24]
#                                                          +- Project [order_id#17, customer_id#18, city#26, trim(category#20, None) AS category#27, product#21, amount#22, order_date#23, status#24]
#                                                             +- Project [order_id#17, customer_id#18, trim(city#19, None) AS city#26, category#20, product#21, amount#22, order_date#23, status#24]
#                                                                +- Relation [order_id#17,customer_id#18,city#19,category#20,product#21,amount#22,order_date#23,status#24] csv
#
# == Analyzed Logical Plan ==
# customer_id: string, total_orders: bigint, total_spend: bigint, avg_order_value: double, first_purchase: date, last_purchase: date, cities_count: bigint, categories_count: bigint, customer_segment: string, overall_rank: int
# Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537]
# +- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537, overall_rank#537]
#    +- Window [rank(total_spend#501L) windowspecdefinition(total_spend#501L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS overall_rank#537], [total_spend#501L DESC NULLS LAST]
#       +- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525]
#          +- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, CASE WHEN ((total_spend#501L >= cast(200000 as bigint)) AND (total_orders#500L >= cast(5 as bigint))) THEN VIP WHEN (total_spend#501L >= cast(100000 as bigint)) THEN Premium ELSE Regular END AS customer_segment#525]
#             +- Aggregate [customer_id#18], [customer_id#18, count(1) AS total_orders#500L, sum(amount_int#33) AS total_spend#501L, avg(amount_int#33) AS avg_order_value#502, min(order_date_clean#35) AS first_purchase#503, max(order_date_clean#35) AS last_purchase#504, count(distinct city#29) AS cities_count#505L, count(distinct category#30) AS categories_count#506L]
#                +- Filter (status#24 = Completed)
#                   +- Deduplicate [order_id#17]
#                      +- Filter (status#24 = Completed)
#                         +- Deduplicate [order_id#17]
#                            +- Filter (status#24 = Completed)
#                               +- Deduplicate [order_id#17]
#                                  +- Deduplicate [order_id#17]
#                                     +- Filter (status#24 = Completed)
#                                        +- Deduplicate [order_id#17]
#                                           +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, amount_int#33, coalesce(to_date(order_date#23, Some(yyyy-MM-dd), Some(Etc/UTC), true), to_date(order_date#23, Some(dd/MM/yyyy), Some(Etc/UTC), true), to_date(order_date#23, Some(yyyy/MM/dd), Some(Etc/UTC), true)) AS order_date_clean#35]
#                                              +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, amount_int#33, coalesce(to_date(order_date#23, Some(yyyy-MM-dd), Some(Etc/UTC), true), to_date(order_date#23, Some(dd/MM/yyyy), Some(Etc/UTC), true), to_date(order_date#23, Some(yyyy/M/dd), Some(Etc/UTC), true)) AS order_date_clean#34]
#                                                 +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, CASE WHEN RLIKE(amount_clean#32, ^[0-9]+$) THEN cast(amount_clean#32 as int) ELSE cast(null as int) END AS amount_int#33]
#                                                    +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, regexp_replace(amount#22, ,, , 1) AS amount_clean#32]
#                                                       +- Project [order_id#17, customer_id#18, city#29, category#30, initcap(product#28) AS product#31, amount#22, order_date#23, status#24]
#                                                          +- Project [order_id#17, customer_id#18, city#29, initcap(category#27) AS category#30, product#28, amount#22, order_date#23, status#24]
#                                                             +- Project [order_id#17, customer_id#18, initcap(city#26) AS city#29, category#27, product#28, amount#22, order_date#23, status#24]
#                                                                +- Project [order_id#17, customer_id#18, city#26, category#27, trim(product#21, None) AS product#28, amount#22, order_date#23, status#24]
#                                                                   +- Project [order_id#17, customer_id#18, city#26, trim(category#20, None) AS category#27, product#21, amount#22, order_date#23, status#24]
#                                                                      +- Project [order_id#17, customer_id#18, trim(city#19, None) AS city#26, category#20, product#21, amount#22, order_date#23, status#24]
#                                                                         +- Relation [order_id#17,customer_id#18,city#19,category#20,product#21,amount#22,order_date#23,status#24] csv
#
# == Optimized Logical Plan ==
# InMemoryRelation [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537], StorageLevel(disk, memory, deserialized, 1 replicas)
#    +- AdaptiveSparkPlan isFinalPlan=false
#       +- Window [rank(total_spend#501L) windowspecdefinition(total_spend#501L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS overall_rank#537], [total_spend#501L DESC NULLS LAST]
#          +- Sort [total_spend#501L DESC NULLS LAST], false, 0
#             +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=331]
#                +- Project [customer_id#767, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, CASE WHEN ((total_spend#501L >= 200000) AND (total_orders#500L >= 5)) THEN VIP WHEN (total_spend#501L >= 100000) THEN Premium ELSE Regular END AS customer_segment#525]
#                   +- HashAggregate(keys=[customer_id#767], functions=[first(count(1)#791L, true), first(sum(amount_int)#793L, true), first(avg(amount_int)#795, true), first(min(order_date_clean)#797, true), first(max(order_date_clean)#799, true), count(city#787), count(category#788)], output=[customer_id#767, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L])
#                      +- Exchange hashpartitioning(customer_id#767, 200), ENSURE_REQUIREMENTS, [plan_id=327]
#                         +- HashAggregate(keys=[customer_id#767], functions=[partial_first(count(1)#791L, true) FILTER (WHERE (gid#786 = 0)), partial_first(sum(amount_int)#793L, true) FILTER (WHERE (gid#786 = 0)), partial_first(avg(amount_int)#795, true) FILTER (WHERE (gid#786 = 0)), partial_first(min(order_date_clean)#797, true) FILTER (WHERE (gid#786 = 0)), partial_first(max(order_date_clean)#799, true) FILTER (WHERE (gid#786 = 0)), partial_count(city#787) FILTER (WHERE (gid#786 = 1)), partial_count(category#788) FILTER (WHERE (gid#786 = 2))], output=[customer_id#767, first#813L, valueSet#814, first#815L, valueSet#816, first#817, valueSet#818, first#819, valueSet#820, first#821, valueSet#822, count#823L, count#824L])
#                            +- HashAggregate(keys=[customer_id#767, city#787, category#788, gid#786], functions=[count(1), sum(amount_int#789), avg(amount_int#789), min(order_date_clean#790), max(order_date_clean#790)], output=[customer_id#767, city#787, category#788, gid#786, count(1)#791L, sum(amount_int)#793L, avg(amount_int)#795, min(order_date_clean)#797, max(order_date_clean)#799])
#                               +- Exchange hashpartitioning(customer_id#767, city#787, category#788, gid#786, 200), ENSURE_REQUIREMENTS, [plan_id=323]
#                                  +- HashAggregate(keys=[customer_id#767, city#787, category#788, gid#786], functions=[partial_count(1), partial_sum(amount_int#789), partial_avg(amount_int#789), partial_min(order_date_clean#790), partial_max(order_date_clean#790)], output=[customer_id#767, city#787, category#788, gid#786, count#831L, sum#832L, sum#833, count#834L, min#835, max#836])
#                                     +- Expand [[customer_id#767, null, null, 0, amount_int#783, order_date_clean#785], [customer_id#767, city#769, null, 1, null, null], [customer_id#767, null, category#771, 2, null, null]], [customer_id#767, city#787, category#788, gid#786, amount_int#789, order_date_clean#790]
#                                        +- Project [customer_id#767, city#769, category#771, amount_int#783, order_date_clean#785]
#                                           +- Filter (isnotnull(status#779) AND (status#779 = Completed))
#                                              +- SortAggregate(key=[order_id#17], functions=[first(customer_id#747, false), first(city#749, false), first(category#751, false), first(status#759, false), first(amount_int#763, false), first(order_date_clean#765, false)], output=[customer_id#767, city#769, category#771, status#779, amount_int#783, order_date_clean#785])
#                                                 +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#747, false), partial_first(city#749, false), partial_first(category#751, false), partial_first(status#759, false), partial_first(amount_int#763, false), partial_first(order_date_clean#765, false)], output=[order_id#17, first#849, valueSet#850, first#851, valueSet#852, first#853, valueSet#854, first#855, valueSet#856, first#857, valueSet#858, first#859, valueSet#860])
#                                                    +- Filter (isnotnull(status#759) AND (status#759 = Completed))
#                                                       +- SortAggregate(key=[order_id#17], functions=[first(customer_id#727, false), first(city#729, false), first(category#731, false), first(status#739, false), first(amount_int#743, false), first(order_date_clean#745, false)], output=[order_id#17, customer_id#747, city#749, category#751, status#759, amount_int#763, order_date_clean#765])
#                                                          +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#727, false), partial_first(city#729, false), partial_first(category#731, false), partial_first(status#739, false), partial_first(amount_int#743, false), partial_first(order_date_clean#745, false)], output=[order_id#17, first#873, valueSet#874, first#875, valueSet#876, first#877, valueSet#878, first#879, valueSet#880, first#881, valueSet#882, first#883, valueSet#884])
#                                                             +- Filter (isnotnull(status#739) AND (status#739 = Completed))
#                                                                +- SortAggregate(key=[order_id#17], functions=[first(customer_id#707, false), first(city#709, false), first(category#711, false), first(status#719, false), first(amount_int#723, false), first(order_date_clean#725, false)], output=[order_id#17, customer_id#727, city#729, category#731, status#739, amount_int#743, order_date_clean#745])
#                                                                   +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#707, false), partial_first(city#709, false), partial_first(category#711, false), partial_first(status#719, false), partial_first(amount_int#723, false), partial_first(order_date_clean#725, false)], output=[order_id#17, first#897, valueSet#898, first#899, valueSet#900, first#901, valueSet#902, first#903, valueSet#904, first#905, valueSet#906, first#907, valueSet#908])
#                                                                      +- SortAggregate(key=[order_id#17], functions=[first(customer_id#687, false), first(city#689, false), first(category#691, false), first(status#699, false), first(amount_int#703, false), first(order_date_clean#705, false)], output=[order_id#17, customer_id#707, city#709, category#711, status#719, amount_int#723, order_date_clean#725])
#                                                                         +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#687, false), partial_first(city#689, false), partial_first(category#691, false), partial_first(status#699, false), partial_first(amount_int#703, false), partial_first(order_date_clean#705, false)], output=[order_id#17, first#921, valueSet#922, first#923, valueSet#924, first#925, valueSet#926, first#927, valueSet#928, first#929, valueSet#930, first#931, valueSet#932])
#                                                                            +- Filter (isnotnull(status#699) AND (status#699 = Completed))
#                                                                               +- SortAggregate(key=[order_id#17], functions=[first(customer_id#18, false), first(city#29, false), first(category#30, false), first(status#24, false), first(amount_int#33, false), first(order_date_clean#35, false)], output=[order_id#17, customer_id#687, city#689, category#691, status#699, amount_int#703, order_date_clean#705])
#                                                                                  +- Sort [order_id#17 ASC NULLS FIRST], false, 0
#                                                                                     +- Exchange hashpartitioning(order_id#17, 200), ENSURE_REQUIREMENTS, [plan_id=304]
#                                                                                        +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#18, false), partial_first(city#29, false), partial_first(category#30, false), partial_first(status#24, false), partial_first(amount_int#33, false), partial_first(order_date_clean#35, false)], output=[order_id#17, first#945, valueSet#946, first#947, valueSet#948, first#949, valueSet#950, first#951, valueSet#952, first#953, valueSet#954, first#955, valueSet#956])
#                                                                                           +- Sort [order_id#17 ASC NULLS FIRST], false, 0
#                                                                                              +- Project [order_id#17, customer_id#18, city#29, category#30, status#24, CASE WHEN RLIKE(amount_clean#32, ^[0-9]+$) THEN cast(amount_clean#32 as int) END AS amount_int#33, coalesce(cast(gettimestamp(order_date#23, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(order_date#23, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(order_date#23, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date)) AS order_date_clean#35]
#                                                                                                 +- Project [order_id#17, customer_id#18, initcap(trim(city#19, None)) AS city#29, initcap(trim(category#20, None)) AS category#30, order_date#23, status#24, regexp_replace(amount#22, ,, , 1) AS amount_clean#32]
#                                                                                                    +- FileScan csv [order_id#17,customer_id#18,city#19,category#20,amount#22,order_date#23,status#24] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/orders.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,city:string,category:string,amount:string,order_date:st...
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- InMemoryTableScan [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537]
#       +- InMemoryRelation [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537], StorageLevel(disk, memory, deserialized, 1 replicas)
#             +- AdaptiveSparkPlan isFinalPlan=false
#                +- Window [rank(total_spend#501L) windowspecdefinition(total_spend#501L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS overall_rank#537], [total_spend#501L DESC NULLS LAST]
#                   +- Sort [total_spend#501L DESC NULLS LAST], false, 0
#                      +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=331]
#                         +- Project [customer_id#767, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, CASE WHEN ((total_spend#501L >= 200000) AND (total_orders#500L >= 5)) THEN VIP WHEN (total_spend#501L >= 100000) THEN Premium ELSE Regular END AS customer_segment#525]
#                            +- HashAggregate(keys=[customer_id#767], functions=[first(count(1)#791L, true), first(sum(amount_int)#793L, true), first(avg(amount_int)#795, true), first(min(order_date_clean)#797, true), first(max(order_date_clean)#799, true), count(city#787), count(category#788)], output=[customer_id#767, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L])
#                               +- Exchange hashpartitioning(customer_id#767, 200), ENSURE_REQUIREMENTS, [plan_id=327]
#                                  +- HashAggregate(keys=[customer_id#767], functions=[partial_first(count(1)#791L, true) FILTER (WHERE (gid#786 = 0)), partial_first(sum(amount_int)#793L, true) FILTER (WHERE (gid#786 = 0)), partial_first(avg(amount_int)#795, true) FILTER (WHERE (gid#786 = 0)), partial_first(min(order_date_clean)#797, true) FILTER (WHERE (gid#786 = 0)), partial_first(max(order_date_clean)#799, true) FILTER (WHERE (gid#786 = 0)), partial_count(city#787) FILTER (WHERE (gid#786 = 1)), partial_count(category#788) FILTER (WHERE (gid#786 = 2))], output=[customer_id#767, first#813L, valueSet#814, first#815L, valueSet#816, first#817, valueSet#818, first#819, valueSet#820, first#821, valueSet#822, count#823L, count#824L])
#                                     +- HashAggregate(keys=[customer_id#767, city#787, category#788, gid#786], functions=[count(1), sum(amount_int#789), avg(amount_int#789), min(order_date_clean#790), max(order_date_clean#790)], output=[customer_id#767, city#787, category#788, gid#786, count(1)#791L, sum(amount_int)#793L, avg(amount_int)#795, min(order_date_clean)#797, max(order_date_clean)#799])
#                                        +- Exchange hashpartitioning(customer_id#767, city#787, category#788, gid#786, 200), ENSURE_REQUIREMENTS, [plan_id=323]
#                                           +- HashAggregate(keys=[customer_id#767, city#787, category#788, gid#786], functions=[partial_count(1), partial_sum(amount_int#789), partial_avg(amount_int#789), partial_min(order_date_clean#790), partial_max(order_date_clean#790)], output=[customer_id#767, city#787, category#788, gid#786, count#831L, sum#832L, sum#833, count#834L, min#835, max#836])
#                                              +- Expand [[customer_id#767, null, null, 0, amount_int#783, order_date_clean#785], [customer_id#767, city#769, null, 1, null, null], [customer_id#767, null, category#771, 2, null, null]], [customer_id#767, city#787, category#788, gid#786, amount_int#789, order_date_clean#790]
#                                                 +- Project [customer_id#767, city#769, category#771, amount_int#783, order_date_clean#785]
#                                                    +- Filter (isnotnull(status#779) AND (status#779 = Completed))
#                                                       +- SortAggregate(key=[order_id#17], functions=[first(customer_id#747, false), first(city#749, false), first(category#751, false), first(status#759, false), first(amount_int#763, false), first(order_date_clean#765, false)], output=[customer_id#767, city#769, category#771, status#779, amount_int#783, order_date_clean#785])
#                                                          +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#747, false), partial_first(city#749, false), partial_first(category#751, false), partial_first(status#759, false), partial_first(amount_int#763, false), partial_first(order_date_clean#765, false)], output=[order_id#17, first#849, valueSet#850, first#851, valueSet#852, first#853, valueSet#854, first#855, valueSet#856, first#857, valueSet#858, first#859, valueSet#860])
#                                                             +- Filter (isnotnull(status#759) AND (status#759 = Completed))
#                                                                +- SortAggregate(key=[order_id#17], functions=[first(customer_id#727, false), first(city#729, false), first(category#731, false), first(status#739, false), first(amount_int#743, false), first(order_date_clean#745, false)], output=[order_id#17, customer_id#747, city#749, category#751, status#759, amount_int#763, order_date_clean#765])
#                                                                   +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#727, false), partial_first(city#729, false), partial_first(category#731, false), partial_first(status#739, false), partial_first(amount_int#743, false), partial_first(order_date_clean#745, false)], output=[order_id#17, first#873, valueSet#874, first#875, valueSet#876, first#877, valueSet#878, first#879, valueSet#880, first#881, valueSet#882, first#883, valueSet#884])
#                                                                      +- Filter (isnotnull(status#739) AND (status#739 = Completed))
#                                                                         +- SortAggregate(key=[order_id#17], functions=[first(customer_id#707, false), first(city#709, false), first(category#711, false), first(status#719, false), first(amount_int#723, false), first(order_date_clean#725, false)], output=[order_id#17, customer_id#727, city#729, category#731, status#739, amount_int#743, order_date_clean#745])
#                                                                            +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#707, false), partial_first(city#709, false), partial_first(category#711, false), partial_first(status#719, false), partial_first(amount_int#723, false), partial_first(order_date_clean#725, false)], output=[order_id#17, first#897, valueSet#898, first#899, valueSet#900, first#901, valueSet#902, first#903, valueSet#904, first#905, valueSet#906, first#907, valueSet#908])
#                                                                               +- SortAggregate(key=[order_id#17], functions=[first(customer_id#687, false), first(city#689, false), first(category#691, false), first(status#699, false), first(amount_int#703, false), first(order_date_clean#705, false)], output=[order_id#17, customer_id#707, city#709, category#711, status#719, amount_int#723, order_date_clean#725])
#                                                                                  +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#687, false), partial_first(city#689, false), partial_first(category#691, false), partial_first(status#699, false), partial_first(amount_int#703, false), partial_first(order_date_clean#705, false)], output=[order_id#17, first#921, valueSet#922, first#923, valueSet#924, first#925, valueSet#926, first#927, valueSet#928, first#929, valueSet#930, first#931, valueSet#932])
#                                                                                     +- Filter (isnotnull(status#699) AND (status#699 = Completed))
#                                                                                        +- SortAggregate(key=[order_id#17], functions=[first(customer_id#18, false), first(city#29, false), first(category#30, false), first(status#24, false), first(amount_int#33, false), first(order_date_clean#35, false)], output=[order_id#17, customer_id#687, city#689, category#691, status#699, amount_int#703, order_date_clean#705])
#                                                                                           +- Sort [order_id#17 ASC NULLS FIRST], false, 0
#                                                                                              +- Exchange hashpartitioning(order_id#17, 200), ENSURE_REQUIREMENTS, [plan_id=304]
#                                                                                                 +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#18, false), partial_first(city#29, false), partial_first(category#30, false), partial_first(status#24, false), partial_first(amount_int#33, false), partial_first(order_date_clean#35, false)], output=[order_id#17, first#945, valueSet#946, first#947, valueSet#948, first#949, valueSet#950, first#951, valueSet#952, first#953, valueSet#954, first#955, valueSet#956])
#                                                                                                    +- Sort [order_id#17 ASC NULLS FIRST], false, 0
#                                                                                                       +- Project [order_id#17, customer_id#18, city#29, category#30, status#24, CASE WHEN RLIKE(amount_clean#32, ^[0-9]+$) THEN cast(amount_clean#32 as int) END AS amount_int#33, coalesce(cast(gettimestamp(order_date#23, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(order_date#23, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(order_date#23, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date)) AS order_date_clean#35]
#                                                                                                          +- Project [order_id#17, customer_id#18, initcap(trim(city#19, None)) AS city#29, initcap(trim(category#20, None)) AS category#30, order_date#23, status#24, regexp_replace(amount#22, ,, , 1) AS amount_clean#32]
#                                                                                                             +- FileScan csv [order_id#17,customer_id#18,city#19,category#20,amount#22,order_date#23,status#24] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/orders.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,city:string,category:string,amount:string,order_date:st...

# %%
segment_data = [
    (1,"VIP"), (2,"Premium"), (3,"Regular")]
segment_df = spark.createDataFrame(
    segment_data, ["segment_code","customer_segment"])
from pyspark.sql.functions import broadcast
customer_segmented = customer_segmented.join(
    broadcast(segment_df),
    "customer_segment",
    "left")

# %%
customer_segmented.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Join UsingJoin(LeftOuter, [customer_segment])
# :- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537]
# :  +- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537, overall_rank#537]
# :     +- Window [rank(total_spend#501L) windowspecdefinition(total_spend#501L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS overall_rank#537], [total_spend#501L DESC NULLS LAST]
# :        +- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525]
# :           +- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, CASE WHEN ((total_spend#501L >= cast(200000 as bigint)) AND (total_orders#500L >= cast(5 as bigint))) THEN VIP WHEN (total_spend#501L >= cast(100000 as bigint)) THEN Premium ELSE Regular END AS customer_segment#525]
# :              +- Aggregate [customer_id#18], [customer_id#18, count(1) AS total_orders#500L, sum(amount_int#33) AS total_spend#501L, avg(amount_int#33) AS avg_order_value#502, min(order_date_clean#35) AS first_purchase#503, max(order_date_clean#35) AS last_purchase#504, count(distinct city#29) AS cities_count#505L, count(distinct category#30) AS categories_count#506L]
# :                 +- Filter (status#24 = Completed)
# :                    +- Deduplicate [order_id#17]
# :                       +- Filter (status#24 = Completed)
# :                          +- Deduplicate [order_id#17]
# :                             +- Filter (status#24 = Completed)
# :                                +- Deduplicate [order_id#17]
# :                                   +- Deduplicate [order_id#17]
# :                                      +- Filter (status#24 = Completed)
# :                                         +- Deduplicate [order_id#17]
# :                                            +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, amount_int#33, coalesce(to_date(order_date#23, Some(yyyy-MM-dd), Some(Etc/UTC), true), to_date(order_date#23, Some(dd/MM/yyyy), Some(Etc/UTC), true), to_date(order_date#23, Some(yyyy/MM/dd), Some(Etc/UTC), true)) AS order_date_clean#35]
# :                                               +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, amount_int#33, coalesce(to_date(order_date#23, Some(yyyy-MM-dd), Some(Etc/UTC), true), to_date(order_date#23, Some(dd/MM/yyyy), Some(Etc/UTC), true), to_date(order_date#23, Some(yyyy/M/dd), Some(Etc/UTC), true)) AS order_date_clean#34]
# :                                                  +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, CASE WHEN RLIKE(amount_clean#32, ^[0-9]+$) THEN cast(amount_clean#32 as int) ELSE cast(null as int) END AS amount_int#33]
# :                                                     +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, regexp_replace(amount#22, ,, , 1) AS amount_clean#32]
# :                                                        +- Project [order_id#17, customer_id#18, city#29, category#30, initcap(product#28) AS product#31, amount#22, order_date#23, status#24]
# :                                                           +- Project [order_id#17, customer_id#18, city#29, initcap(category#27) AS category#30, product#28, amount#22, order_date#23, status#24]
# :                                                              +- Project [order_id#17, customer_id#18, initcap(city#26) AS city#29, category#27, product#28, amount#22, order_date#23, status#24]
# :                                                                 +- Project [order_id#17, customer_id#18, city#26, category#27, trim(product#21, None) AS product#28, amount#22, order_date#23, status#24]
# :                                                                    +- Project [order_id#17, customer_id#18, city#26, trim(category#20, None) AS category#27, product#21, amount#22, order_date#23, status#24]
# :                                                                       +- Project [order_id#17, customer_id#18, trim(city#19, None) AS city#26, category#20, product#21, amount#22, order_date#23, status#24]
# :                                                                          +- Relation [order_id#17,customer_id#18,city#19,category#20,product#21,amount#22,order_date#23,status#24] csv
# +- ResolvedHint (strategy=broadcast)
#    +- LogicalRDD [segment_code#1169L, customer_segment#1170], false
#
# == Analyzed Logical Plan ==
# customer_segment: string, customer_id: string, total_orders: bigint, total_spend: bigint, avg_order_value: double, first_purchase: date, last_purchase: date, cities_count: bigint, categories_count: bigint, overall_rank: int, segment_code: bigint
# Project [customer_segment#525, customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, overall_rank#537, segment_code#1169L]
# +- Join LeftOuter, (customer_segment#525 = customer_segment#1170)
#    :- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537]
#    :  +- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537, overall_rank#537]
#    :     +- Window [rank(total_spend#501L) windowspecdefinition(total_spend#501L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS overall_rank#537], [total_spend#501L DESC NULLS LAST]
#    :        +- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525]
#    :           +- Project [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, CASE WHEN ((total_spend#501L >= cast(200000 as bigint)) AND (total_orders#500L >= cast(5 as bigint))) THEN VIP WHEN (total_spend#501L >= cast(100000 as bigint)) THEN Premium ELSE Regular END AS customer_segment#525]
#    :              +- Aggregate [customer_id#18], [customer_id#18, count(1) AS total_orders#500L, sum(amount_int#33) AS total_spend#501L, avg(amount_int#33) AS avg_order_value#502, min(order_date_clean#35) AS first_purchase#503, max(order_date_clean#35) AS last_purchase#504, count(distinct city#29) AS cities_count#505L, count(distinct category#30) AS categories_count#506L]
#    :                 +- Filter (status#24 = Completed)
#    :                    +- Deduplicate [order_id#17]
#    :                       +- Filter (status#24 = Completed)
#    :                          +- Deduplicate [order_id#17]
#    :                             +- Filter (status#24 = Completed)
#    :                                +- Deduplicate [order_id#17]
#    :                                   +- Deduplicate [order_id#17]
#    :                                      +- Filter (status#24 = Completed)
#    :                                         +- Deduplicate [order_id#17]
#    :                                            +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, amount_int#33, coalesce(to_date(order_date#23, Some(yyyy-MM-dd), Some(Etc/UTC), true), to_date(order_date#23, Some(dd/MM/yyyy), Some(Etc/UTC), true), to_date(order_date#23, Some(yyyy/MM/dd), Some(Etc/UTC), true)) AS order_date_clean#35]
#    :                                               +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, amount_int#33, coalesce(to_date(order_date#23, Some(yyyy-MM-dd), Some(Etc/UTC), true), to_date(order_date#23, Some(dd/MM/yyyy), Some(Etc/UTC), true), to_date(order_date#23, Some(yyyy/M/dd), Some(Etc/UTC), true)) AS order_date_clean#34]
#    :                                                  +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, amount_clean#32, CASE WHEN RLIKE(amount_clean#32, ^[0-9]+$) THEN cast(amount_clean#32 as int) ELSE cast(null as int) END AS amount_int#33]
#    :                                                     +- Project [order_id#17, customer_id#18, city#29, category#30, product#31, amount#22, order_date#23, status#24, regexp_replace(amount#22, ,, , 1) AS amount_clean#32]
#    :                                                        +- Project [order_id#17, customer_id#18, city#29, category#30, initcap(product#28) AS product#31, amount#22, order_date#23, status#24]
#    :                                                           +- Project [order_id#17, customer_id#18, city#29, initcap(category#27) AS category#30, product#28, amount#22, order_date#23, status#24]
#    :                                                              +- Project [order_id#17, customer_id#18, initcap(city#26) AS city#29, category#27, product#28, amount#22, order_date#23, status#24]
#    :                                                                 +- Project [order_id#17, customer_id#18, city#26, category#27, trim(product#21, None) AS product#28, amount#22, order_date#23, status#24]
#    :                                                                    +- Project [order_id#17, customer_id#18, city#26, trim(category#20, None) AS category#27, product#21, amount#22, order_date#23, status#24]
#    :                                                                       +- Project [order_id#17, customer_id#18, trim(city#19, None) AS city#26, category#20, product#21, amount#22, order_date#23, status#24]
#    :                                                                          +- Relation [order_id#17,customer_id#18,city#19,category#20,product#21,amount#22,order_date#23,status#24] csv
#    +- ResolvedHint (strategy=broadcast)
#       +- LogicalRDD [segment_code#1169L, customer_segment#1170], false
#
# == Optimized Logical Plan ==
# Project [customer_segment#525, customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, overall_rank#537, segment_code#1169L]
# +- Join LeftOuter, (customer_segment#525 = customer_segment#1170), rightHint=(strategy=broadcast)
#    :- InMemoryRelation [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :     +- AdaptiveSparkPlan isFinalPlan=false
#    :        +- Window [rank(total_spend#501L) windowspecdefinition(total_spend#501L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS overall_rank#537], [total_spend#501L DESC NULLS LAST]
#    :           +- Sort [total_spend#501L DESC NULLS LAST], false, 0
#    :              +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=331]
#    :                 +- Project [customer_id#767, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, CASE WHEN ((total_spend#501L >= 200000) AND (total_orders#500L >= 5)) THEN VIP WHEN (total_spend#501L >= 100000) THEN Premium ELSE Regular END AS customer_segment#525]
#    :                    +- HashAggregate(keys=[customer_id#767], functions=[first(count(1)#791L, true), first(sum(amount_int)#793L, true), first(avg(amount_int)#795, true), first(min(order_date_clean)#797, true), first(max(order_date_clean)#799, true), count(city#787), count(category#788)], output=[customer_id#767, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L])
#    :                       +- Exchange hashpartitioning(customer_id#767, 200), ENSURE_REQUIREMENTS, [plan_id=327]
#    :                          +- HashAggregate(keys=[customer_id#767], functions=[partial_first(count(1)#791L, true) FILTER (WHERE (gid#786 = 0)), partial_first(sum(amount_int)#793L, true) FILTER (WHERE (gid#786 = 0)), partial_first(avg(amount_int)#795, true) FILTER (WHERE (gid#786 = 0)), partial_first(min(order_date_clean)#797, true) FILTER (WHERE (gid#786 = 0)), partial_first(max(order_date_clean)#799, true) FILTER (WHERE (gid#786 = 0)), partial_count(city#787) FILTER (WHERE (gid#786 = 1)), partial_count(category#788) FILTER (WHERE (gid#786 = 2))], output=[customer_id#767, first#813L, valueSet#814, first#815L, valueSet#816, first#817, valueSet#818, first#819, valueSet#820, first#821, valueSet#822, count#823L, count#824L])
#    :                             +- HashAggregate(keys=[customer_id#767, city#787, category#788, gid#786], functions=[count(1), sum(amount_int#789), avg(amount_int#789), min(order_date_clean#790), max(order_date_clean#790)], output=[customer_id#767, city#787, category#788, gid#786, count(1)#791L, sum(amount_int)#793L, avg(amount_int)#795, min(order_date_clean)#797, max(order_date_clean)#799])
#    :                                +- Exchange hashpartitioning(customer_id#767, city#787, category#788, gid#786, 200), ENSURE_REQUIREMENTS, [plan_id=323]
#    :                                   +- HashAggregate(keys=[customer_id#767, city#787, category#788, gid#786], functions=[partial_count(1), partial_sum(amount_int#789), partial_avg(amount_int#789), partial_min(order_date_clean#790), partial_max(order_date_clean#790)], output=[customer_id#767, city#787, category#788, gid#786, count#831L, sum#832L, sum#833, count#834L, min#835, max#836])
#    :                                      +- Expand [[customer_id#767, null, null, 0, amount_int#783, order_date_clean#785], [customer_id#767, city#769, null, 1, null, null], [customer_id#767, null, category#771, 2, null, null]], [customer_id#767, city#787, category#788, gid#786, amount_int#789, order_date_clean#790]
#    :                                         +- Project [customer_id#767, city#769, category#771, amount_int#783, order_date_clean#785]
#    :                                            +- Filter (isnotnull(status#779) AND (status#779 = Completed))
#    :                                               +- SortAggregate(key=[order_id#17], functions=[first(customer_id#747, false), first(city#749, false), first(category#751, false), first(status#759, false), first(amount_int#763, false), first(order_date_clean#765, false)], output=[customer_id#767, city#769, category#771, status#779, amount_int#783, order_date_clean#785])
#    :                                                  +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#747, false), partial_first(city#749, false), partial_first(category#751, false), partial_first(status#759, false), partial_first(amount_int#763, false), partial_first(order_date_clean#765, false)], output=[order_id#17, first#849, valueSet#850, first#851, valueSet#852, first#853, valueSet#854, first#855, valueSet#856, first#857, valueSet#858, first#859, valueSet#860])
#    :                                                     +- Filter (isnotnull(status#759) AND (status#759 = Completed))
#    :                                                        +- SortAggregate(key=[order_id#17], functions=[first(customer_id#727, false), first(city#729, false), first(category#731, false), first(status#739, false), first(amount_int#743, false), first(order_date_clean#745, false)], output=[order_id#17, customer_id#747, city#749, category#751, status#759, amount_int#763, order_date_clean#765])
#    :                                                           +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#727, false), partial_first(city#729, false), partial_first(category#731, false), partial_first(status#739, false), partial_first(amount_int#743, false), partial_first(order_date_clean#745, false)], output=[order_id#17, first#873, valueSet#874, first#875, valueSet#876, first#877, valueSet#878, first#879, valueSet#880, first#881, valueSet#882, first#883, valueSet#884])
#    :                                                              +- Filter (isnotnull(status#739) AND (status#739 = Completed))
#    :                                                                 +- SortAggregate(key=[order_id#17], functions=[first(customer_id#707, false), first(city#709, false), first(category#711, false), first(status#719, false), first(amount_int#723, false), first(order_date_clean#725, false)], output=[order_id#17, customer_id#727, city#729, category#731, status#739, amount_int#743, order_date_clean#745])
#    :                                                                    +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#707, false), partial_first(city#709, false), partial_first(category#711, false), partial_first(status#719, false), partial_first(amount_int#723, false), partial_first(order_date_clean#725, false)], output=[order_id#17, first#897, valueSet#898, first#899, valueSet#900, first#901, valueSet#902, first#903, valueSet#904, first#905, valueSet#906, first#907, valueSet#908])
#    :                                                                       +- SortAggregate(key=[order_id#17], functions=[first(customer_id#687, false), first(city#689, false), first(category#691, false), first(status#699, false), first(amount_int#703, false), first(order_date_clean#705, false)], output=[order_id#17, customer_id#707, city#709, category#711, status#719, amount_int#723, order_date_clean#725])
#    :                                                                          +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#687, false), partial_first(city#689, false), partial_first(category#691, false), partial_first(status#699, false), partial_first(amount_int#703, false), partial_first(order_date_clean#705, false)], output=[order_id#17, first#921, valueSet#922, first#923, valueSet#924, first#925, valueSet#926, first#927, valueSet#928, first#929, valueSet#930, first#931, valueSet#932])
#    :                                                                             +- Filter (isnotnull(status#699) AND (status#699 = Completed))
#    :                                                                                +- SortAggregate(key=[order_id#17], functions=[first(customer_id#18, false), first(city#29, false), first(category#30, false), first(status#24, false), first(amount_int#33, false), first(order_date_clean#35, false)], output=[order_id#17, customer_id#687, city#689, category#691, status#699, amount_int#703, order_date_clean#705])
#    :                                                                                   +- Sort [order_id#17 ASC NULLS FIRST], false, 0
#    :                                                                                      +- Exchange hashpartitioning(order_id#17, 200), ENSURE_REQUIREMENTS, [plan_id=304]
#    :                                                                                         +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#18, false), partial_first(city#29, false), partial_first(category#30, false), partial_first(status#24, false), partial_first(amount_int#33, false), partial_first(order_date_clean#35, false)], output=[order_id#17, first#945, valueSet#946, first#947, valueSet#948, first#949, valueSet#950, first#951, valueSet#952, first#953, valueSet#954, first#955, valueSet#956])
#    :                                                                                            +- Sort [order_id#17 ASC NULLS FIRST], false, 0
#    :                                                                                               +- Project [order_id#17, customer_id#18, city#29, category#30, status#24, CASE WHEN RLIKE(amount_clean#32, ^[0-9]+$) THEN cast(amount_clean#32 as int) END AS amount_int#33, coalesce(cast(gettimestamp(order_date#23, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(order_date#23, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(order_date#23, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date)) AS order_date_clean#35]
#    :                                                                                                  +- Project [order_id#17, customer_id#18, initcap(trim(city#19, None)) AS city#29, initcap(trim(category#20, None)) AS category#30, order_date#23, status#24, regexp_replace(amount#22, ,, , 1) AS amount_clean#32]
#    :                                                                                                     +- FileScan csv [order_id#17,customer_id#18,city#19,category#20,amount#22,order_date#23,status#24] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/orders.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,city:string,category:string,amount:string,order_date:st...
#    +- Filter isnotnull(customer_segment#1170)
#       +- LogicalRDD [segment_code#1169L, customer_segment#1170], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [customer_segment#525, customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, overall_rank#537, segment_code#1169L]
#    +- BroadcastHashJoin [customer_segment#525], [customer_segment#1170], LeftOuter, BuildRight, false
#       :- InMemoryTableScan [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537]
#       :     +- InMemoryRelation [customer_id#18, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, customer_segment#525, overall_rank#537], StorageLevel(disk, memory, deserialized, 1 replicas)
#       :           +- AdaptiveSparkPlan isFinalPlan=false
#       :              +- Window [rank(total_spend#501L) windowspecdefinition(total_spend#501L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS overall_rank#537], [total_spend#501L DESC NULLS LAST]
#       :                 +- Sort [total_spend#501L DESC NULLS LAST], false, 0
#       :                    +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=331]
#       :                       +- Project [customer_id#767, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L, CASE WHEN ((total_spend#501L >= 200000) AND (total_orders#500L >= 5)) THEN VIP WHEN (total_spend#501L >= 100000) THEN Premium ELSE Regular END AS customer_segment#525]
#       :                          +- HashAggregate(keys=[customer_id#767], functions=[first(count(1)#791L, true), first(sum(amount_int)#793L, true), first(avg(amount_int)#795, true), first(min(order_date_clean)#797, true), first(max(order_date_clean)#799, true), count(city#787), count(category#788)], output=[customer_id#767, total_orders#500L, total_spend#501L, avg_order_value#502, first_purchase#503, last_purchase#504, cities_count#505L, categories_count#506L])
#       :                             +- Exchange hashpartitioning(customer_id#767, 200), ENSURE_REQUIREMENTS, [plan_id=327]
#       :                                +- HashAggregate(keys=[customer_id#767], functions=[partial_first(count(1)#791L, true) FILTER (WHERE (gid#786 = 0)), partial_first(sum(amount_int)#793L, true) FILTER (WHERE (gid#786 = 0)), partial_first(avg(amount_int)#795, true) FILTER (WHERE (gid#786 = 0)), partial_first(min(order_date_clean)#797, true) FILTER (WHERE (gid#786 = 0)), partial_first(max(order_date_clean)#799, true) FILTER (WHERE (gid#786 = 0)), partial_count(city#787) FILTER (WHERE (gid#786 = 1)), partial_count(category#788) FILTER (WHERE (gid#786 = 2))], output=[customer_id#767, first#813L, valueSet#814, first#815L, valueSet#816, first#817, valueSet#818, first#819, valueSet#820, first#821, valueSet#822, count#823L, count#824L])
#       :                                   +- HashAggregate(keys=[customer_id#767, city#787, category#788, gid#786], functions=[count(1), sum(amount_int#789), avg(amount_int#789), min(order_date_clean#790), max(order_date_clean#790)], output=[customer_id#767, city#787, category#788, gid#786, count(1)#791L, sum(amount_int)#793L, avg(amount_int)#795, min(order_date_clean)#797, max(order_date_clean)#799])
#       :                                      +- Exchange hashpartitioning(customer_id#767, city#787, category#788, gid#786, 200), ENSURE_REQUIREMENTS, [plan_id=323]
#       :                                         +- HashAggregate(keys=[customer_id#767, city#787, category#788, gid#786], functions=[partial_count(1), partial_sum(amount_int#789), partial_avg(amount_int#789), partial_min(order_date_clean#790), partial_max(order_date_clean#790)], output=[customer_id#767, city#787, category#788, gid#786, count#831L, sum#832L, sum#833, count#834L, min#835, max#836])
#       :                                            +- Expand [[customer_id#767, null, null, 0, amount_int#783, order_date_clean#785], [customer_id#767, city#769, null, 1, null, null], [customer_id#767, null, category#771, 2, null, null]], [customer_id#767, city#787, category#788, gid#786, amount_int#789, order_date_clean#790]
#       :                                               +- Project [customer_id#767, city#769, category#771, amount_int#783, order_date_clean#785]
#       :                                                  +- Filter (isnotnull(status#779) AND (status#779 = Completed))
#       :                                                     +- SortAggregate(key=[order_id#17], functions=[first(customer_id#747, false), first(city#749, false), first(category#751, false), first(status#759, false), first(amount_int#763, false), first(order_date_clean#765, false)], output=[customer_id#767, city#769, category#771, status#779, amount_int#783, order_date_clean#785])
#       :                                                        +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#747, false), partial_first(city#749, false), partial_first(category#751, false), partial_first(status#759, false), partial_first(amount_int#763, false), partial_first(order_date_clean#765, false)], output=[order_id#17, first#849, valueSet#850, first#851, valueSet#852, first#853, valueSet#854, first#855, valueSet#856, first#857, valueSet#858, first#859, valueSet#860])
#       :                                                           +- Filter (isnotnull(status#759) AND (status#759 = Completed))
#       :                                                              +- SortAggregate(key=[order_id#17], functions=[first(customer_id#727, false), first(city#729, false), first(category#731, false), first(status#739, false), first(amount_int#743, false), first(order_date_clean#745, false)], output=[order_id#17, customer_id#747, city#749, category#751, status#759, amount_int#763, order_date_clean#765])
#       :                                                                 +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#727, false), partial_first(city#729, false), partial_first(category#731, false), partial_first(status#739, false), partial_first(amount_int#743, false), partial_first(order_date_clean#745, false)], output=[order_id#17, first#873, valueSet#874, first#875, valueSet#876, first#877, valueSet#878, first#879, valueSet#880, first#881, valueSet#882, first#883, valueSet#884])
#       :                                                                    +- Filter (isnotnull(status#739) AND (status#739 = Completed))
#       :                                                                       +- SortAggregate(key=[order_id#17], functions=[first(customer_id#707, false), first(city#709, false), first(category#711, false), first(status#719, false), first(amount_int#723, false), first(order_date_clean#725, false)], output=[order_id#17, customer_id#727, city#729, category#731, status#739, amount_int#743, order_date_clean#745])
#       :                                                                          +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#707, false), partial_first(city#709, false), partial_first(category#711, false), partial_first(status#719, false), partial_first(amount_int#723, false), partial_first(order_date_clean#725, false)], output=[order_id#17, first#897, valueSet#898, first#899, valueSet#900, first#901, valueSet#902, first#903, valueSet#904, first#905, valueSet#906, first#907, valueSet#908])
#       :                                                                             +- SortAggregate(key=[order_id#17], functions=[first(customer_id#687, false), first(city#689, false), first(category#691, false), first(status#699, false), first(amount_int#703, false), first(order_date_clean#705, false)], output=[order_id#17, customer_id#707, city#709, category#711, status#719, amount_int#723, order_date_clean#725])
#       :                                                                                +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#687, false), partial_first(city#689, false), partial_first(category#691, false), partial_first(status#699, false), partial_first(amount_int#703, false), partial_first(order_date_clean#705, false)], output=[order_id#17, first#921, valueSet#922, first#923, valueSet#924, first#925, valueSet#926, first#927, valueSet#928, first#929, valueSet#930, first#931, valueSet#932])
#       :                                                                                   +- Filter (isnotnull(status#699) AND (status#699 = Completed))
#       :                                                                                      +- SortAggregate(key=[order_id#17], functions=[first(customer_id#18, false), first(city#29, false), first(category#30, false), first(status#24, false), first(amount_int#33, false), first(order_date_clean#35, false)], output=[order_id#17, customer_id#687, city#689, category#691, status#699, amount_int#703, order_date_clean#705])
#       :                                                                                         +- Sort [order_id#17 ASC NULLS FIRST], false, 0
#       :                                                                                            +- Exchange hashpartitioning(order_id#17, 200), ENSURE_REQUIREMENTS, [plan_id=304]
#       :                                                                                               +- SortAggregate(key=[order_id#17], functions=[partial_first(customer_id#18, false), partial_first(city#29, false), partial_first(category#30, false), partial_first(status#24, false), partial_first(amount_int#33, false), partial_first(order_date_clean#35, false)], output=[order_id#17, first#945, valueSet#946, first#947, valueSet#948, first#949, valueSet#950, first#951, valueSet#952, first#953, valueSet#954, first#955, valueSet#956])
#       :                                                                                                  +- Sort [order_id#17 ASC NULLS FIRST], false, 0
#       :                                                                                                     +- Project [order_id#17, customer_id#18, city#29, category#30, status#24, CASE WHEN RLIKE(amount_clean#32, ^[0-9]+$) THEN cast(amount_clean#32 as int) END AS amount_int#33, coalesce(cast(gettimestamp(order_date#23, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(order_date#23, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(order_date#23, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date)) AS order_date_clean#35]
#       :                                                                                                        +- Project [order_id#17, customer_id#18, initcap(trim(city#19, None)) AS city#29, initcap(trim(category#20, None)) AS category#30, order_date#23, status#24, regexp_replace(amount#22, ,, , 1) AS amount_clean#32]
#       :                                                                                                           +- FileScan csv [order_id#17,customer_id#18,city#19,category#20,amount#22,order_date#23,status#24] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/orders.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,city:string,category:string,amount:string,order_date:st...
#       +- BroadcastExchange HashedRelationBroadcastMode(List(input[1, string, false]),false), [plan_id=358]
#          +- Filter isnotnull(customer_segment#1170)
#             +- Scan ExistingRDD[segment_code#1169L,customer_segment#1170]

# %%
#sort:
customer_segmented.orderBy(
    col('total_spend').desc(),
    col('total_orders').desc()
)
# Out:
# DataFrame[customer_segment: string, customer_id: string, total_orders: bigint, total_spend: bigint, avg_order_value: double, first_purchase: date, last_purchase: date, cities_count: bigint, categories_count: bigint, overall_rank: int, segment_code: bigint]

# %%
#set operations
electronics = clean_orders_df.filter(col("category")=="Electronics") \
                             .select("customer_id")
grocery = clean_orders_df.filter(col("category")=="Grocery") \
                          .select("customer_id")
both = electronics.intersect(grocery)
only_one = electronics.subtract(grocery)

# %%
#storage strategy
customer_segmented.write.mode("overwrite")\
     .partitionBy("customer_segment")\
     .parquet("customer_master")
monthly_df.write.mode("overwrite").orc("monthly_analytics")

# %%
#debugging
df=df.groupBy("customer_id").sum("amount")
df.show()
#.show() returns none,not dataframe
